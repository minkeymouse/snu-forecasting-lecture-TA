# %% [markdown]
# # 경제 분석 및 예측과 데이터 지능 실습4: Dynamic Factor Model
#
# OECD데이터를 활용해 VAR 분석을 실습합니다. Statsmodels을 주로 다루고, 실제 데이터에 적용해 봅니다.
#
# 실습 전 터미널에 아래 코드를 실행하여 환경설정을 맞춰줍니다.
#
# conda env update -n forecasting_lecture -f environment.yml --prune

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
import matplotlib.pyplot as plt

# %%
# 1. 데이터 로드 및 전처리
# --------------------------
df = pd.read_csv('../datasets/querterly_oecd_account_data.csv',
                 parse_dates=['date'])
df['date'] = df['date'].dt.to_period('Q')

vars_to_use = ['Y', 'C', 'G', 'I', 'EX', 'IM']

# %%
df
# Out:
#      country    date           Y           C          G          I         EX  \
# 0        CAN  1990Q1   1015714.7    518707.4   271355.6   223461.1   207736.8
# 1        DEU  1990Q1   3220806.5   1811014.8   569128.8   725261.2   527153.8
# 2        FRA  1990Q1   2244890.8   1170205.4   554966.9   517196.6   352329.9
# 3        GBR  1990Q1   2038060.5   1141647.3   450827.1   404835.9   345478.9
# 4        IRL  1990Q1     99243.7     47489.0    21623.8    23005.3    29526.0
# ...      ...     ...         ...         ...        ...        ...        ...
# 1510     ITA  2024Q4   3058928.9   1722741.8   577189.2   687706.9   947135.2
# 1511     JPN  2024Q4   5685249.7   3019732.3  1192953.7  1395443.7  1041559.3
# 1512     KOR  2024Q4   2761625.7   1325159.4   482440.0   796442.2  1105866.4
# 1513     MEX  2024Q4   2825213.5   1966980.1   314718.3   699365.0  1144131.3
# 1514     USA  2024Q4  24804425.0  17028435.1  3373352.2  5364654.6  2644303.5
#
#              IM
# 0      200021.9
# 1      489620.3
# 2      353194.4
# 3      331416.2
# 4       33508.4
# ...         ...
# 1510   851761.5
# 1511   962723.9
# 1512   947051.6
# 1513  1253890.4
# 1514  3648546.5
#
# [1515 rows x 8 columns]

# %% [markdown]
# ### 분기별 변화율을 계산하고 연도별 변화율로 annualize 합니다.
#
# pct_change : $\frac{x_t - x_{t-1}}{x_{t-1}}$

# %%
# 국가별 분기 대비 성장률을 연율화하여 계산
df_growth = (
    df.set_index(['date','country'])[vars_to_use]
      .sort_index()
      .groupby('country')
      .pct_change()   # 전분기 대비 % 변화
      .mul(400)       # 연율화
      .dropna()
      .reset_index()
)

# %%
df_growth
# Out:
#         date country         Y         C         G          I         EX  \
# 0     1990Q2     CAN -1.604899 -4.397470 -4.739021  -9.666649  14.559000
# 1     1990Q2     DEU  1.966650  4.530985  4.203548  -1.872153 -12.497074
# 2     1990Q2     FRA  2.149022  2.356373  1.528379   1.493049 -10.373233
# 3     1990Q2     GBR  2.691736  4.575984  1.491037  -5.702558  -0.884917
# 4     1990Q2     IRL  8.237097 -0.163406  6.587186  11.475616   7.192305
# ...      ...     ...       ...       ...       ...        ...        ...
# 1499  2024Q4     ITA  0.542257  0.782655  0.723357   6.426822  -0.686788
# 1500  2024Q4     JPN  2.224569  0.126873  1.603582   0.851373   4.068308
# 1501  2024Q4     KOR  0.264860  0.957007  2.823791  -6.445716   3.100825
# 1502  2024Q4     MEX -2.527285 -5.636310 -0.384355  -6.206416  14.533305
# 1503  2024Q4     USA  2.428260  3.975812  2.863977  -0.298287  -0.155852
#
#             IM
# 0     0.972094
# 1     4.329396
# 2     2.894383
# 3    -1.072971
# 4     1.866995
# ...        ...
# 1499 -1.514761
# 1500 -8.566318
# 1501  0.482371
# 1502  4.841508
# 1503 -1.898891
#
# [1504 rows x 8 columns]

# %%
# 와이드 패널로 피벗(MultiIndex 컬럼)
panel = df_growth.pivot(
    index='date',
    columns='country',
    values=vars_to_use
)

# 결측은 제거하지 않고 전/후 값으로 채움
panel = panel.interpolate().ffill().bfill()

# 상수가 된 시계열은 제거
panel = panel.loc[:, panel.std() > 0]

# 이제 MultiIndex를 단일 문자열로 평탄화: "Y_CAN", "C_DEU" 등
panel.columns = [f"{var}_{ctry}" for var, ctry in panel.columns]

# 표준화(평균=0, 표준편차=1)
endog = (panel - panel.mean()) / panel.std()

# %%
panel
# Out:
#            Y_CAN      Y_DEU     Y_FRA     Y_GBR     Y_IND      Y_IRL  \
# date
# 1990Q2 -1.604899   1.966650  2.149022  2.691736  1.955917   8.237097
# 1990Q3 -2.866674   8.423731  2.599187 -4.391767  1.955917   5.030833
# 1990Q4 -3.561647   7.041689 -0.192075 -2.028692  1.955917   1.818620
# 1991Q1 -5.754445  10.874742  1.052461 -1.970087  1.955917   0.099391
# 1991Q2  1.919836  -1.751893  1.477162 -0.462038  1.955917   0.090439
# ...          ...        ...       ...       ...       ...        ...
# 2023Q4  0.701022  -1.485721  1.943732 -0.829848  7.170527  -8.909823
# 2024Q1  1.817139   0.946324  0.295674  3.623950  6.755978   6.380011
# 2024Q2  2.741968  -1.182501  1.036824  1.831079  4.607702  -1.411571
# 2024Q3  2.195033   0.420835  1.632968  0.003127  5.513931  16.234170
# 2024Q4  2.587046  -0.802584 -0.405217  0.381500  6.548331  14.451633
#
#            Y_ITA      Y_JPN      Y_KOR     Y_MEX  ...     IM_DEU     IM_FRA  \
# date                                              ...
# 1990Q2  1.219137  12.615878   9.017118  8.679217  ...   4.329396   2.894383
# 1990Q3  0.641380   6.706963  14.174941  5.456557  ...  30.772830   1.781925
# 1990Q4 -2.598346  -0.759920   7.626647  5.083811  ...  20.966204  -2.419467
# 1991Q1  4.000091   3.485273  14.634599  1.102419  ...   6.329821  13.562836
# 1991Q2  2.168677   4.745645   6.817302  6.120906  ...   2.665105   0.000654
# ...          ...        ...        ...       ...  ...        ...        ...
# 2023Q4  0.803995   0.085450   1.820070  1.462541  ...  -8.149187  -7.252476
# 2024Q1  1.362850  -2.071618   5.200438 -0.127350  ...   4.397360  -0.690182
# 2024Q2  0.303030   3.208850  -0.910578  1.149389  ...   4.915888   0.984152
# 2024Q3  0.048297   1.420241   0.398353  3.660818  ...   2.341987  -1.244410
# 2024Q4  0.542257   2.224569   0.264860 -2.527285  ...   2.191412   1.409449
#
#            IM_GBR     IM_IND     IM_IRL     IM_ITA     IM_JPN     IM_KOR  \
# date
# 1990Q2  -1.072971  76.635117   1.866995   8.595439   4.303179  10.942332
# 1990Q3  -6.765434  76.635117   0.577458  -1.925537  -4.798272  12.815959
# 1990Q4  -6.869520  76.635117   0.246786  27.492700  21.939681  18.652478
# 1991Q1 -13.293236  76.635117   1.106296 -21.662423 -23.565770  24.304653
# 1991Q2   1.763537  76.635117   3.007021  12.196338   0.305165  19.347305
# ...           ...        ...        ...        ...        ...        ...
# 2023Q4   3.851561 -30.851565  52.081818  -4.351215  12.361432   6.579925
# 2024Q1  -1.627130  -3.278002 -25.507611  -0.290350 -11.090645  -1.701894
# 2024Q2  21.951850  18.718829  18.670763   0.635443  12.059576   6.287616
# 2024Q3 -11.328298   6.857668   8.837355   4.625800   7.856880   6.481105
# 2024Q4  11.414226 -25.335178  -7.760739  -1.514761  -8.566318   0.482371
#
#            IM_MEX     IM_USA
# date
# 1990Q2   0.887507  -0.670707
# 1990Q3  58.360235  -1.615312
# 1990Q4  11.311060 -10.727253
# 1991Q1 -12.891911  -4.558196
# 1991Q2  29.685205   7.109352
# ...           ...        ...
# 2023Q4   0.213147   4.149710
# 2024Q1   7.883325   6.001667
# 2024Q2   2.062720   7.360122
# 2024Q3   5.891628  10.335447
# 2024Q4   4.841508  -1.898891
#
# [139 rows x 66 columns]

# %%
# 2. DynamicFactorMQ 설정 및 적합
# ---------------------------------
k_factors  = 3   # 공통 요인 개수
factor_ord = 4   # 요인 동학의 VAR 차수

model = sm.tsa.DynamicFactorMQ(
    endog,
    factors=k_factors,
    factor_orders=factor_ord,
    idiosyncratic_ar1=True,
    standardize=False
)

# %%
results = model.fit(disp=False)
print(results.summary())
# Out:
#                                Dynamic Factor Results
# ===================================================================================
# Dep. Variable:        "Y_CAN", and 65 more   No. Observations:                  139
# Model:                Dynamic Factor Model   Log Likelihood               -8477.334
#                    + 3 factors in 3 blocks   AIC                          17644.668
#                      + AR(1) idiosyncratic   BIC                          18657.061
# Date:                     Thu, 18 Jun 2026   HQIC                         18056.077
# Time:                             21:42:22   EM Iterations                      122
# Sample:                         06-30-1990
#                               - 12-31-2024
# Covariance Type:              Not computed
#                                 Observation equation:
# =====================================================================================
# Factor loadings:          0          1          2    idiosyncratic: AR(1)        var.
# -------------------------------------------------------------------------------------
#            Y_CAN       0.17       0.00      -0.07                    0.27        0.10
#            Y_DEU       0.16      -0.01       0.09                   -0.08        0.21
#            Y_FRA       0.17       0.08       0.02                   -0.09        0.03
#            Y_GBR       0.17       0.06      -0.01                   -0.19        0.08
#            Y_IND       0.15       0.06      -0.13                   -0.06        0.17
#            Y_IRL       0.07       0.03       0.05                   -0.13        0.81
#            Y_ITA       0.17       0.07       0.06                    0.09        0.05
#            Y_JPN       0.13      -0.08       0.04                   -0.20        0.38
#            Y_KOR       0.07      -0.09       0.20                    0.28        0.54
#            Y_MEX       0.16      -0.03      -0.08                    0.18        0.15
#            Y_USA       0.17       0.01      -0.05                    0.02        0.16
#            C_CAN       0.16       0.07      -0.07                   -0.09        0.10
#            C_DEU       0.15       0.13       0.07                    0.04        0.19
#            C_FRA       0.15       0.15       0.05                   -0.25        0.08
#            C_GBR       0.16       0.10       0.01                   -0.17        0.16
#            C_IND       0.11       0.05      -0.15                   -0.34        0.42
#            C_IRL       0.13       0.09       0.12                   -0.22        0.33
#            C_ITA       0.15       0.12       0.11                    0.03        0.11
#            C_JPN       0.12      -0.03       0.00                   -0.28        0.51
#            C_KOR       0.03      -0.03       0.26                    0.19        0.64
#            C_MEX       0.16      -0.04      -0.09                    0.11        0.19
#            C_USA       0.17       0.06      -0.02                    0.13        0.14
#            G_CAN       0.10       0.08      -0.08                   -0.03        0.60
#            G_DEU       0.04       0.07      -0.00                   -0.15        0.89
#            G_FRA       0.16       0.12      -0.02                    0.66        0.05
#            G_GBR       0.15       0.09      -0.02                   -0.16        0.25
#            G_IND      -0.03      -0.01      -0.06                   -0.28        0.88
#            G_IRL      -0.02       0.01       0.02                   -0.21        0.94
#            G_ITA       0.04       0.03      -0.03                   -0.17        0.92
#            G_JPN       0.03       0.04       0.16                   -0.12        0.82
#            G_KOR      -0.01       0.05       0.03                   -0.18        0.93
#            G_MEX       0.01      -0.03       0.03                   -0.27        0.86
#            G_USA      -0.06       0.04       0.00                    0.11        0.88
#            I_CAN       0.14      -0.07      -0.04                    0.24        0.35
#            I_DEU       0.08      -0.09       0.11                   -0.18        0.70
#            I_FRA       0.16       0.04       0.02                    0.35        0.18
#            I_GBR       0.13       0.01      -0.02                   -0.24        0.50
#            I_IND       0.16       0.07      -0.06                    0.13        0.20
#            I_IRL       0.03       0.02      -0.03                   -0.40        0.81
#            I_ITA       0.14       0.08       0.07                    0.14        0.28
#            I_JPN       0.03      -0.11       0.10                   -0.01        0.83
#            I_KOR       0.02      -0.07       0.17                    0.17        0.78
#            I_MEX       0.12      -0.04      -0.10                    0.39        0.43
#            I_USA       0.11      -0.12      -0.08                    0.47        0.36
#           EX_CAN       0.13      -0.08      -0.05                   -0.01        0.41
#           EX_DEU       0.14      -0.08       0.04                   -0.16        0.31
#           EX_FRA       0.16      -0.04       0.01                   -0.11        0.15
#           EX_GBR       0.07      -0.11       0.06                   -0.18        0.71
#           EX_IND       0.04      -0.05       0.14                    0.69        0.41
#           EX_IRL       0.05      -0.01      -0.02                   -0.11        0.92
#           EX_ITA       0.17      -0.01       0.01                    0.21        0.15
#           EX_JPN       0.11      -0.16       0.05                   -0.04        0.40
#           EX_KOR       0.11      -0.07       0.02                   -0.08        0.62
#           EX_MEX       0.13      -0.02      -0.01                   -0.19        0.37
#           EX_USA       0.15      -0.10      -0.01                    0.09        0.19
#           IM_CAN       0.16      -0.07      -0.05                   -0.08        0.21
#           IM_DEU       0.13      -0.08       0.02                   -0.10        0.42
#           IM_FRA       0.16      -0.03       0.06                    0.01        0.24
#           IM_GBR       0.13      -0.04      -0.06                   -0.23        0.43
#           IM_IND       0.08      -0.06       0.01                    0.39        0.64
#           IM_IRL       0.05      -0.01      -0.05                   -0.54        0.64
#           IM_ITA       0.14      -0.04       0.03                    0.04        0.36
#           IM_JPN       0.02      -0.20       0.11                   -0.08        0.61
#           IM_KOR       0.05      -0.10       0.18                    0.02        0.67
#           IM_MEX       0.13      -0.12      -0.06                   -0.06        0.39
#           IM_USA       0.16      -0.09      -0.03                    0.38        0.13
#                         Transition: Factor block 0
# =========================================================================
#                  L1.0       L2.0       L3.0        L4.0    error variance
# -------------------------------------------------------------------------
#          0      -0.16      -0.10      -0.02       -0.03             29.25
#                         Transition: Factor block 1
# =========================================================================
#                  L1.1       L2.1       L3.1        L4.1    error variance
# -------------------------------------------------------------------------
#          1       0.27      -0.19       0.07        0.03              7.42
#                         Transition: Factor block 2
# =========================================================================
#                  L1.2       L2.2       L3.2        L4.2    error variance
# -------------------------------------------------------------------------
#          2       0.08      -0.11       0.14        0.30              3.15
# =========================================================================
#
# Warnings:
# [1] Covariance matrix not calculated.

# %%
# 3. 평활화된 요인 추출 및 시각화
# -----------------------------------
factors = results.factors.smoothed
plt.figure(figsize=(10, 4))
for col in factors.columns:
    plt.plot(factors.index.to_timestamp(), factors[col], label=col)
plt.title("Smoothed Common Factors")
plt.xlabel("Date")
plt.ylabel("Factor Value")
plt.legend()
plt.tight_layout()
plt.show()

# %%
# 4. 예측
# --------------
fc_res  = results.get_forecast(steps=16)
fc_mean = fc_res.predicted_mean
fc_ci   = fc_res.conf_int()

# "lower Y_CAN"을 "Y_CAN_lower" 등으로 이름 변경
fc_ci.columns = [
    f"{name.split(' ',1)[1]}_{name.split(' ',1)[0]}"
    for name in fc_ci.columns
]

# %%
endog.columns
# Out:
# Index(['Y_CAN', 'Y_DEU', 'Y_FRA', 'Y_GBR', 'Y_IND', 'Y_IRL', 'Y_ITA', 'Y_JPN',
#        'Y_KOR', 'Y_MEX', 'Y_USA', 'C_CAN', 'C_DEU', 'C_FRA', 'C_GBR', 'C_IND',
#        'C_IRL', 'C_ITA', 'C_JPN', 'C_KOR', 'C_MEX', 'C_USA', 'G_CAN', 'G_DEU',
#        'G_FRA', 'G_GBR', 'G_IND', 'G_IRL', 'G_ITA', 'G_JPN', 'G_KOR', 'G_MEX',
#        'G_USA', 'I_CAN', 'I_DEU', 'I_FRA', 'I_GBR', 'I_IND', 'I_IRL', 'I_ITA',
#        'I_JPN', 'I_KOR', 'I_MEX', 'I_USA', 'EX_CAN', 'EX_DEU', 'EX_FRA',
#        'EX_GBR', 'EX_IND', 'EX_IRL', 'EX_ITA', 'EX_JPN', 'EX_KOR', 'EX_MEX',
#        'EX_USA', 'IM_CAN', 'IM_DEU', 'IM_FRA', 'IM_GBR', 'IM_IND', 'IM_IRL',
#        'IM_ITA', 'IM_JPN', 'IM_KOR', 'IM_MEX', 'IM_USA'],
#       dtype='str')

# %%
series = "Y_KOR"
plt.figure(figsize=(10,4))
plt.plot(endog.index.to_timestamp(), endog[series], label="Observed")
plt.plot(fc_mean.index.to_timestamp(), fc_mean[series], label="Forecast")
plt.fill_between(
    fc_ci.index.to_timestamp(),
    fc_ci[f"{series}_lower"],
    fc_ci[f"{series}_upper"],
    color='gray', alpha=0.3
)
plt.title(f"{series}: In-Sample & Out-of-Sample")
plt.xlabel("Date")
plt.ylabel("Standardized Growth")
plt.legend()
plt.tight_layout()
plt.show()

# %%
# 5. 진단
# --------------
# 시계열별 Ljung–Box p-값
lb_pvals = {
    col: sm.stats.acorr_ljungbox(results.resid[col], lags=[10], return_df=True)
               ['lb_pvalue'].iloc[0]
    for col in results.resid.columns
}
lb_df = pd.DataFrame.from_dict(
    lb_pvals, orient='index',
    columns=['Ljung-Box p-value (lag=10)']
)
print("\nLjung-Box test:\n", lb_df)
# Out:
# Ljung-Box test:
#          Ljung-Box p-value (lag=10)
# Y_CAN                     0.949511
# Y_DEU                     0.662279
# Y_FRA                     0.898482
# Y_GBR                     0.591868
# Y_IND                     0.001418
# ...                            ...
# IM_ITA                    0.004023
# IM_JPN                    0.227427
# IM_KOR                    0.101877
# IM_MEX                    0.703488
# IM_USA                    0.572683
#
# [66 rows x 1 columns]

# %%
results.get_coefficients_of_determination()
# Out:
#                0         1         2
# Y_CAN   0.865622  0.001769  0.033460
# Y_DEU   0.762435  0.000193  0.032595
# Y_FRA   0.915685  0.065917  0.001384
# Y_GBR   0.886840  0.035227  0.001229
# Y_IND   0.708788  0.035325  0.112756
# ...          ...       ...       ...
# IM_ITA  0.625978  0.015222  0.002079
# IM_JPN  0.008524  0.325954  0.043797
# IM_KOR  0.075360  0.086540  0.176474
# IM_MEX  0.479819  0.103453  0.013823
# IM_USA  0.771283  0.046218  0.005307
#
# [66 rows x 3 columns]

# %%
results.plot_coefficients_of_determination()
plt.tight_layout()
plt.show()
